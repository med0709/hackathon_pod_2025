# %% [markdown]
# ## Iniciando o Spark

# %%
# !pip install pyspark

# %%
# !rm -f spark-3.1.2-bin-hadoop3.2.tgz
# !rm -rf spark-3.1.2-bin-hadoop3.2
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null
# !wget -q https://archive.apache.org/dist/spark/spark-3.1.2/spark-3.1.2-bin-hadoop3.2.tgz
# !tar xf spark-3.1.2-bin-hadoop3.2.tgz
# !pip install -q findspark

# %%
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-3.1.2-bin-hadoop3.2"

# %%
import findspark
findspark.init()
from pyspark.sql import SparkSession
spark = SparkSession.builder.master("local[*]").getOrCreate()

# %%
spark

# %% [markdown]
# ## Importando bibliotecas

# %%
from pyspark.sql.functions import input_file_name, split, col, lit, regexp_replace
from datetime import datetime, timedelta
from pyspark.sql.functions import col, count, when, isnull, isnan, countDistinct, round, variance, stddev

# %% [markdown]
# ### Montando o drive do Colab

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %%
from pyspark.sql import SparkSession

spark = SparkSession \
    .builder \
    .appName("Hackathon 2025") \
    .config('spark.ui.port', '4050') \
    .getOrCreate()

# %%
#Criar uma função para registrar a data atual
def log():
  return datetime.now().strftime('%Y-%m-%d %H:%M:%S') +' >>>'

# %% [markdown]
# ### Importando os dados

# %%
# Localizacao das camadas

raw_path = '/content/gdrive/MyDrive/hackathon_pod_2025/camada_raw/'
silver_path = '/content/gdrive/MyDrive/hackathon_pod_2025/camada_silver/'

# %% [markdown]
# #### Processamento

# %%
# Carregar dados da camada raw em formato parquet e aplicar as transformações iniciais
df_bronze = spark.read.format("parquet").load(raw_path, header=True).select(
    col('NUM_CPF').alias('NumCpf'),
    col('SAFRA').alias('Safra'),
    col('FLAG_INSTALACAO').cast('boolean').alias('IsSetup'),
    col('FPD').cast('boolean').alias('IsFPD'),
    col('PROD').alias('ProductDescription'),
    col('flag_mig2').alias('ProductMigration'),
    col('var_26').cast('int').alias('Var26'),
    col('var_27').cast('int').alias('Var27'),
    col('var_28').cast('int').alias('Var28'),
    col('var_29').cast('int').alias('Var29'),
    col('var_30').cast('int').alias('Var30'),
    col('var_31').cast('int').alias('Var31'),
    col('var_32').cast('int').alias('Var32'),
    col('var_33').cast('int').alias('Var33'),
    col('var_34').cast('int').alias('Var34'),
    col('var_35').cast('int').alias('Var35'),
    col('var_36').cast('int').alias('Var36'),
    col('var_37').cast('int').alias('Var37'),
    col('var_38').cast('int').alias('Var38'),
    col('var_39').cast('int').alias('Var39'),
    col('var_40').cast('int').alias('Var40'),
    col('var_41').cast('int').alias('Var41'),
    col('var_42').cast('int').alias('Var42'),
    col('var_43').cast('int').alias('Var43'),
    col('var_44').cast('int').alias('Var44'),
    col('var_45').cast('int').alias('Var45'),
    col('var_46').cast('int').alias('Var46'),
    col('var_47').cast('int').alias('Var47'),
    col('var_48').cast('int').alias('Var48'),
    col('var_49').cast('int').alias('Var49'),
    col('var_50').cast('int').alias('Var50'),
    col('var_51').cast('int').alias('Var51'),
    col('var_52').cast('int').alias('Var52'),
    col('var_53').cast('int').alias('Var53'),
    col('var_54').cast('int').alias('Var54'),
    col('var_55').cast('int').alias('Var55'),
    col('var_56').cast('int').alias('Var56'),
    col('var_57').cast('int').alias('Var57'),
    col('var_58').cast('int').alias('Var58'),
    col('var_59').cast('int').alias('Var59'),
    col('var_60').cast('int').alias('Var60'),
    col('var_61').cast('int').alias('Var61'),
    col('var_62').cast('int').alias('Var62'),
    col('var_63').cast('int').alias('Var63'),
    col('var_64').cast('int').alias('Var64'),
    col('var_65').cast('int').alias('Var65'),
    col('var_66').cast('int').alias('Var66'),
    col('var_67').cast('int').alias('Var67'),
    col('var_68').cast('int').alias('Var68'),
    col('var_69').cast('int').alias('Var69'),
    col('var_70').cast('int').alias('Var70'),
    col('var_71').cast('int').alias('Var71'),
    col('var_72').cast('int').alias('Var72'),
    col('var_73').cast('int').alias('Var73'),
    col('var_74').cast('int').alias('Var74'),
    col('var_75').cast('int').alias('Var75'),
    col('var_76').cast('int').alias('Var76'),
    col('var_77').cast('int').alias('Var77'),
    col('var_78').cast('int').alias('Var78'),
    col('var_79').cast('int').alias('Var79'),
    col('var_80').cast('int').alias('Var80'),
    col('var_81').cast('int').alias('Var81'),
    col('var_82').cast('int').alias('Var82'),
    col('var_83').cast('int').alias('Var83'),
    col('var_84').cast('int').alias('Var84'),
    col('var_85').cast('int').alias('Var85'),
    col('var_86').cast('int').alias('Var86'),
    col('var_87').cast('int').alias('Var87'),
    col('var_88').cast('int').alias('Var88'),
    col('var_89').cast('int').alias('Var89'),
    col('var_90').cast('int').alias('Var90'),
    col('var_91').cast('int').alias('Var91'),
    col('var_92').cast('int').alias('Var92'),
    col('var_93').cast('int').alias('Var93')
)

# %%
# Verificando o esquema da tabela
df_bronze.printSchema()

# %%
# Agora iremos criar as variaveis ano e mes a partir da variavel safra
df_base_dados_cadastrais = (df_bronze \
    .withColumn('Safra', to_date(col('Safra'), 'yyyyMM')) \
    .withColumn('Ano', year(col('Safra'))) \
    .withColumn('Mes', month(col('Safra')))
)

# %%
## Vamos carregar a tabela silver na camada silver
df_silver = spark.read.format("parquet").load(silver_path)

# %%
df_silver.write\
    .mode("overwrite")\
    .partitionBy('Safra')\
    .parquet(silver_path)
